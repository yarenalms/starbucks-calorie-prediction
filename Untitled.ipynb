# %%
 # !pip install lightgbm
 # !pip install catboost
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.2/99.2 MB 6.4 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from lightgbm import LGBMRegressor
from catboost import CatBoostRegressor
from sklearn.neural_network import MLPRegressor
from sklearn.metrics import accuracy_score, r2_score, mean_squared_error
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
from google.colab import files
uploaded = files.upload()

import pandas as pd
df = pd.read_csv("starbucks.csv")  # yüklediğin dosya adını yaz
# Out:
#      <input type="file" id="files-0d23c865-4785-461a-b3cb-76aca82434b0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0d23c865-4785-461a-b3cb-76aca82434b0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df
# Out:
#     Unnamed: 0                                   item  calories   fat  carb  \
# 0            1                           8-Grain Roll       350   8.0    67
# 1            2                      Apple Bran Muffin       350   9.0    64
# 2            3                          Apple Fritter       420  20.0    59
# 3            4                        Banana Nut Loaf       490  19.0    75
# 4            5            Birthday Cake Mini Doughnut       130   6.0    17
# ..         ...                                    ...       ...   ...   ...
# 72          73        Tarragon Chicken Salad Sandwich       420  13.0    46
# 73          74                Turkey & Swiss Sandwich       390  13.0    36
# 74          75             Greek Yogurt Honey Parfait       300  12.0    44
# 75          76         Peach Raspberry Yogurt Parfait       300   4.0    57
# 76          77  Strawberry & Blueberry Yogurt Parfait       300   3.5    60
#
#     fiber  protein      type
# ...

# %%
df = df.drop('Unnamed: 0', axis=1)

# %%
df
# Out:
#                                      item  calories   fat  carb  fiber  \
# 0                            8-Grain Roll       350   8.0    67      5
# 1                       Apple Bran Muffin       350   9.0    64      7
# 2                           Apple Fritter       420  20.0    59      0
# 3                         Banana Nut Loaf       490  19.0    75      4
# 4             Birthday Cake Mini Doughnut       130   6.0    17      0
# ..                                    ...       ...   ...   ...    ...
# 72        Tarragon Chicken Salad Sandwich       420  13.0    46      6
# 73                Turkey & Swiss Sandwich       390  13.0    36      2
# 74             Greek Yogurt Honey Parfait       300  12.0    44      0
# 75         Peach Raspberry Yogurt Parfait       300   4.0    57      3
# 76  Strawberry & Blueberry Yogurt Parfait       300   3.5    60      3
#
#     protein      type
# 0        10    bakery
# 1         6    bakery
# 2         5    bakery
# ...

# %%
df.info() #sütunun kaç tane eksik veri içerdiğini ve veri tipini gösterir
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   item      77 non-null     object
#  1   calories  77 non-null     int64
#  2   fat       77 non-null     float64
#  3   carb      77 non-null     int64
#  4   fiber     77 non-null     int64
#  5   protein   77 non-null     int64
#  6   type      77 non-null     object
# dtypes: float64(1), int64(4), object(2)
# memory usage: 4.3+ KB

# %%
df.isnull().sum() #eksik veri sayısını gösterir
# Out:
# item        0
# calories    0
# fat         0
# carb        0
# fiber       0
# protein     0
# type        0
# dtype: int64

# %%
df['type'].unique() #sütundaki kategorileri göstermek için
# Out:
# array(['bakery', 'bistro box', 'petite', 'hot breakfast', 'salad',
#        'sandwich', 'parfait'], dtype=object)

# %%
df.groupby('type').count() # her kategori için, o kategoriye ait diğer sütunlarda kaç tane veri olduğunu verir.
# Out:
#                item  calories  fat  carb  fiber  protein
# type
# bakery           41        41   41    41     41       41
# bistro box        8         8    8     8      8        8
# hot breakfast     8         8    8     8      8        8
# parfait           3         3    3     3      3        3
# petite            9         9    9     9      9        9
# salad             1         1    1     1      1        1
# sandwich          7         7    7     7      7        7

# %%
df.groupby('type')['item'].count()
# Out:
# type
# bakery           41
# bistro box        8
# hot breakfast     8
# parfait           3
# petite            9
# salad             1
# sandwich          7
# Name: item, dtype: int64

# %%
type_counts = df.groupby('type')['item'].count().reset_index()
plt.figure(figsize=(8, 5))
sns.barplot(x='type', y='item', data=type_counts, palette='rocket');  #Her type kategorisi için ürün sayısı hesaplanır.

# %%
sns.barplot(x='type', y='calories', data=df, palette='rocket');  #her 'type' kategorisi için ortalama kalori miktarını gösterir.

# %%
#korelasyon ısı haritası
df.corr()
plt.figure(figsize=(10, 10))
sns.heatmap(df.corr(), annot=True);
plt.title('Correlation Heatmap'); #sayısal ve kategorik değişkenler arasındaki ilişkiler

# %%
df.hist(figsize=(10, 8), bins=10, color='c', edgecolor='k')
plt.suptitle("Histograms of Numerical Variables")
plt.show()  #sayısal sütunların dağılımını gösteren histogramlar (sıklık grafikleri) çizer.

# Her bir grafik, ilgili değişkenin değer aralıklarında kaç adet ürün olduğunu görselleştiriyor.

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x="fat", y="protein", hue="calories", size="calories", data=df, palette="coolwarm", sizes=(20, 200))
plt.title("Fat and Protein Distribution")
plt.show()  #yağ ve protein miktarının kaloriye etkisi

# %%
plt.figure(figsize=(12,6))
df.groupby('type')[['calories', 'fat', 'carb', 'protein']].mean().plot(kind='bar')
plt.title('Average Nutritional Values ​​by Food Types')
plt.xticks(rotation=45)
plt.legend(bbox_to_anchor=(1.05, 1))
plt.tight_layout()
plt.show() #yiyecek türlerine göre otomatik besin değerleri

# %%
sns.pairplot(df, hue='type'); #ürün türlerinin besin değerlerine göre nasıl dağıldığı

# %%
df = pd.get_dummies(df,columns=['type'], drop_first=True) #kategorik veriyi sayısala çevirme one-hot encoding
#Makine öğrenmesi modelleri (örneğin LinearRegression, RandomForest) kategorik verilerle doğrudan çalışamaz.
#Bu nedenle kategorik değişkenler önce sayısal hale getirilmelidir.

# %%
df.head()
# Out:
#                           item  calories   fat  carb  fiber  protein  \
# 0                 8-Grain Roll       350   8.0    67      5       10
# 1            Apple Bran Muffin       350   9.0    64      7        6
# 2                Apple Fritter       420  20.0    59      0        5
# 3              Banana Nut Loaf       490  19.0    75      4        7
# 4  Birthday Cake Mini Doughnut       130   6.0    17      0        0
#
#    type_bistro box  type_hot breakfast  type_parfait  type_petite  type_salad  \
# 0            False               False         False        False       False
# 1            False               False         False        False       False
# 2            False               False         False        False       False
# 3            False               False         False        False       False
# 4            False               False         False        False       False
#
#    type_sandwich
# 0          False
# 1          False
# 2          False
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   item                77 non-null     object
#  1   calories            77 non-null     int64
#  2   fat                 77 non-null     float64
#  3   carb                77 non-null     int64
#  4   fiber               77 non-null     int64
#  5   protein             77 non-null     int64
#  6   type_bistro box     77 non-null     bool
#  7   type_hot breakfast  77 non-null     bool
#  8   type_parfait        77 non-null     bool
#  9   type_petite         77 non-null     bool
#  10  type_salad          77 non-null     bool
#  11  type_sandwich       77 non-null     bool
# dtypes: bool(6), float64(1), int64(4), object(1)
# memory usage: 4.2+ KB

# %%
df.describe() #veri setindeki sayısal sütunların istatistiksel özetini verir
# Out:
#          calories        fat       carb      fiber    protein
# count   77.000000  77.000000  77.000000  77.000000  77.000000
# mean   338.831169  13.766234  44.870130   2.220779   9.480519
# std    105.368701   7.095488  16.551634   2.112764   8.079556
# min     80.000000   0.000000  16.000000   0.000000   0.000000
# 25%    300.000000   9.000000  31.000000   0.000000   5.000000
# 50%    350.000000  13.000000  45.000000   2.000000   7.000000
# 75%    420.000000  18.000000  59.000000   4.000000  15.000000
# max    500.000000  28.000000  80.000000   7.000000  34.000000

# %%
df = df.drop('item', axis=1)

# %%
df.shape
# Out:
# (77, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   calories            77 non-null     int64
#  1   fat                 77 non-null     float64
#  2   carb                77 non-null     int64
#  3   fiber               77 non-null     int64
#  4   protein             77 non-null     int64
#  5   type_bistro box     77 non-null     bool
#  6   type_hot breakfast  77 non-null     bool
#  7   type_parfait        77 non-null     bool
#  8   type_petite         77 non-null     bool
#  9   type_salad          77 non-null     bool
#  10  type_sandwich       77 non-null     bool
# dtypes: bool(6), float64(1), int64(4)
# memory usage: 3.6 KB

# %%
df
# Out:
#     calories   fat  carb  fiber  protein  type_bistro box  type_hot breakfast  \
# 0        350   8.0    67      5       10            False               False
# 1        350   9.0    64      7        6            False               False
# 2        420  20.0    59      0        5            False               False
# 3        490  19.0    75      4        7            False               False
# 4        130   6.0    17      0        0            False               False
# ..       ...   ...   ...    ...      ...              ...                 ...
# 72       420  13.0    46      6       32            False               False
# 73       390  13.0    36      2       34            False               False
# 74       300  12.0    44      0        8            False               False
# 75       300   4.0    57      3       10            False               False
# 76       300   3.5    60      3        7            False               False
#
# ...

# %%
x = df.drop('calories',axis=1)
y = df[['calories']]   # veri setini bağımsız değişkenler (özellikler) ve bağımlı değişken (hedef) olarak ayırır

# %%
#X → Girdi özellikleri

#y → Tahmin edilmek istenen hedef

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, train_size=0.80, random_state=42) #Veriyi rastgele karıştırarak %80 eğitim, %20 test verisine böler

# %%
x_test.shape
# Out:
# (16, 10)

# %%
rf = RandomForestRegressor(n_estimators=600, random_state=42)
model_rf = rf.fit(x_train, y_train) #birçok karar ağacı oluşturarak çalışan bir ensemble (topluluk) algoritmasıdır. Regresyon problemlerinde, bu ağaçların ortalamasını alarak tahmin yapar.
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:1389: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)

# %%
model_rf.score(x_test, y_test)
# Out:
# 0.9328518833259388

# %%
y_pred = model_rf.predict(x_test)

mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"Mean Squared Error: {mse}")
print(f"R² Score: {r2}")
# Out:
# Mean Squared Error: 1024.7432118055556
# R² Score: 0.9328518833259388

# %%
plt.figure(figsize=(10, 6))
plt.plot(y_test.values, label='Actual')
plt.plot(y_pred, label='Predicted')
plt.legend(prop=dict(size=14))
plt.title('Actual vs Predicted Calories of Test Dataset')
plt.xlabel('Data Points')
plt.ylabel('Calories')
plt.show()

# %%
lr = LinearRegression()
model_lr = lr.fit(x_train, y_train)
#Bağımsız değişkenler (örneğin: fat, carb, protein...) ile bağımlı değişken (calories) arasında doğrusal (lineer) bir ilişki olduğunu varsayar.

# %%
model_lr.score(x_test, y_test)
# Out:
# 0.9930687931839743

# %%
y_pred = model_lr.predict(x_test)

mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"Mean Squared Error: {mse}")
print(f"R² Score: {r2}")
# Out:
# Mean Squared Error: 105.77671401894082
# R² Score: 0.9930687931839743

# %%
plt.figure(figsize=(10, 6))
plt.plot(y_test.values, label='Actual')
plt.plot(y_pred, label='Predicted')
plt.legend(prop=dict(size=14))
plt.title('Actual vs Predicted Calories of Test Dataset')
plt.xlabel('Data Points')
plt.ylabel('Calories')
plt.show()

# %%
gbm = GradientBoostingRegressor(random_state=42, learning_rate=0.5, max_depth=4, n_estimators=400, subsample=0.5)
#Birden çok zayıf tahminci (genellikle karar ağaçları) arka arkaya eğitilir.

#Her ağaç, bir önceki ağacın hatalarını öğrenmeye çalışır.

# %%
model_gbm = gbm.fit(x_train, y_train)
model_gbm.score(x_test, y_test)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/ensemble/_gb.py:672: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)  # TODO: Is this still required?
# 0.9738130503937129

# %%
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"Mean Squared Error: {mse}")
print(f"R² Score: {r2}")
# Out:
# Mean Squared Error: 105.77671401894082
# R² Score: 0.9930687931839743

# %%
plt.figure(figsize=(10, 6))
plt.plot(y_test.values, label='Actual')
plt.plot(y_pred, label='Predicted')
plt.legend(prop=dict(size=14))
plt.title('Actual vs Predicted Calories of Test Dataset')
plt.xlabel('Data Points')
plt.ylabel('Calories')
plt.show()

# %%
knn = KNeighborsRegressor(n_neighbors=1)
model_knn = knn.fit(x_train, y_train)
model_knn.score(x_test, y_test)
#Bu model, test verisindeki her ürün için, eğitim verisinde ona en çok benzeyen 1 ürünü bulur ve o ürünün kalorisini tahmin olarak verir.
# Out:
# 0.9561789700010238

# %%
y_pred = model_knn.predict(x_test)

# %%
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"Mean Squared Error: {mse}")
print(f"R² Score: {r2}")
# Out:
# Mean Squared Error: 668.75
# R² Score: 0.9561789700010238

# %%
plt.figure(figsize=(10, 6))
plt.plot(y_test.values, label='Actual')
plt.plot(y_pred, label='Predicted')
plt.legend(prop=dict(size=14))
plt.title('Actual vs Predicted Calories of Test Dataset')
plt.xlabel('Data Points')
plt.ylabel('Calories')
plt.show()

# %%
svr = SVR(kernel="linear", C=6)
svr_model = svr.fit(x_train, y_train)
#SVR, hataların bir eşiği aşmamasını sağlamaya çalışır (ε-insensitive margin).
#	Doğrusal regresyon modeli kullanılır. Kalori ile girişler arasında doğrusal ilişki varsayılır.
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
svr_model.score(x_test, y_test)
# Out:
# 0.9943433686184033

# %%
y_pred = svr_model.predict(x_test)

# %%
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"Mean Squared Error: {mse}")
print(f"R² Score: {r2}")
# Out:
# Mean Squared Error: 86.32549797508611
# R² Score: 0.9943433686184033

# %%
plt.figure(figsize=(10, 6))
plt.plot(y_test.values, label='Actual')
plt.plot(y_pred, label='Predicted')
plt.legend(prop=dict(size=14))
plt.title('Actual vs Predicted Calories of Test Dataset')
plt.xlabel('Data Points')
plt.ylabel('Calories')
plt.show()

# %%
lgbm = LGBMRegressor(learning_rate=0.1, n_estimators=500, max_depth=4, verbose=-1)
lgbm_model = lgbm.fit(x_train, y_train)
lgbm_model.score(x_test, y_test) #karar ağaçları üzerine kurulu bir boosting algoritmasıdır
# Out:
# 0.8741455407843808

# %%
y_pred = lgbm_model.predict(x_test)

# %%
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"Mean Squared Error: {mse}")
print(f"R² Score: {r2}")
# Out:
# Mean Squared Error: 1920.657036185864
# R² Score: 0.8741455407843808

# %%
plt.figure(figsize=(10, 6))
plt.plot(y_test.values, label='Actual')
plt.plot(y_pred, label='Predicted')
plt.legend(prop=dict(size=14))
plt.title('Actual vs Predicted Calories of Test Dataset')
plt.xlabel('Data Points')
plt.ylabel('Calories')
plt.show()

# %%
catb = CatBoostRegressor(iterations=200, learning_rate=0.1, depth=3, verbose=0)
model_catb = catb.fit(x_train, y_train)
#Gradient Boosting (art arda ağaç eğitme) algoritmasına dayalı, çok güçlü bir regresyon modelidir.

# %%
model_catb.score(x_test, y_test)
# Out:
# np.float64(0.966404526419992)

# %%
y_pred = model_catb.predict(x_test)

# %%
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"Mean Squared Error: {mse}")
print(f"R² Score: {r2}")
# Out:
# Mean Squared Error: 512.6984225874031
# R² Score: 0.966404526419992

# %%
plt.figure(figsize=(10, 6))
plt.plot(y_test.values, label='Actual')
plt.plot(y_pred, label='Predicted')
plt.legend(prop=dict(size=14))
plt.title('Actual vs Predicted Calories of Test Dataset')
plt.xlabel('Data Points')
plt.ylabel('Calories')
plt.show()

# %%
mlp = MLPRegressor(learning_rate_init=0.1, max_iter=100, random_state=42, hidden_layer_sizes=(100, 50))
mlp_model = mlp.fit(x_train, y_train)
mlp_model.score(x_test, y_test)
#MLPRegressor, scikit-learn kütüphanesinde yer alan bir yapay sinir ağı modelidir (Multi-Layer Perceptron, yani çok katmanlı algılayıcı).
#Bu model, doğrusal olmayan ve karmaşık ilişkileri öğrenerek sürekli (sayısal) değerleri tahmin etmek için kullanılır.
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:1650: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 0.9961179586398871

# %%
y_pred = mlp_model.predict(x_test)

# %%
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"Mean Squared Error: {mse}")
print(f"R² Score: {r2}")
# Out:
# Mean Squared Error: 59.2435905690984
# R² Score: 0.9961179586398871

# %%
plt.figure(figsize=(10, 6))
plt.plot(y_test.values, label='Actual')
plt.plot(y_pred, label='Predicted')
plt.legend(prop=dict(size=14))
plt.title('Actual vs Predicted Calories of Test Dataset')
plt.xlabel('Data Points')
plt.ylabel('Calories')
plt.show()

# %%
y_pred_all = mlp_model.predict(x)

plt.figure(figsize=(10, 6))
plt.plot(y.values, label='Actual')
plt.plot(y_pred_all, label='Predicted')
plt.legend(prop=dict(size=14))
plt.title('Actual vs Predicted Calories of Full Dataset')
plt.xlabel('Data Points')
plt.ylabel('Calories')
plt.show()

# %%
#linear
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import pandas as pd

# Eğitim ve test tahminleri
y_train_pred = model_lr.predict(x_train)
y_test_pred = model_lr.predict(x_test)

# Metrik hesaplamaları
train_mse = mean_squared_error(y_train, y_train_pred)
train_mae = mean_absolute_error(y_train, y_train_pred)
train_r2 = r2_score(y_train, y_train_pred)

test_mse = mean_squared_error(y_test, y_test_pred)
test_mae = mean_absolute_error(y_test, y_test_pred)
test_r2 = r2_score(y_test, y_test_pred)

# Karşılaştırma tablosu
comparison_df = pd.DataFrame({
    'Metric': ['Mean Squared Error', 'Mean Absolute Error', 'R² Score'],
    'Train Score': [train_mse, train_mae, train_r2],
    'Test Score': [test_mse, test_mae, test_r2]
})

print(comparison_df)
# Out:
#                 Metric  Train Score  Test Score
# 0   Mean Squared Error    94.348181  105.776714
# 1  Mean Absolute Error     7.213673    8.434753
# 2             R² Score     0.990046    0.993069

# %%
# Kullanıcıdan giriş alınması
fat = float(input("Yağ (gram): "))
carb = float(input("Karbonhidrat (gram): "))
fiber = float(input("Lif (gram): "))
protein = float(input("Protein (gram): "))
food_type = input("Ürün tipi (bakery, bistro box, hot breakfast, parfait, petite, salad, sandwich): ").strip()

# Kalori tahmini yapılması
kalori_tahmini = predict_calories(
    model=model_lr,
    fat=fat,
    carb=carb,
    fiber=fiber,
    protein=protein,
    food_type=food_type,
    encoder_columns=model_lr.feature_names_in_
)

print(f"\n➡️ Tahmin Edilen Kalori: {kalori_tahmini[0]:.2f} kcal")
# Out:
# Yağ (gram): 9
# Karbonhidrat (gram): 33
# Lif (gram): 2
# Protein (gram): 4
# Ürün tipi (bakery, bistro box, hot breakfast, parfait, petite, salad, sandwich): bakery
#
# ➡️ Tahmin Edilen Kalori: 232.29 kcal
